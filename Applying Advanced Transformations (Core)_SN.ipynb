# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df = pd.read_csv('C:/Users/Shaun/Documents/GitHub/YELP_API/superhero_info - superhero_info.csv')
df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df1 = pd.read_csv('C:/Users/Shaun/Documents/GitHub/YELP_API/superhero_powers - superhero_powers.csv')
df1.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
## adding expand=True
df['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
df[['Hero','Publisher']] = df['Hero|Publisher'].str.split('|',expand=True)
df.head(5)
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
## drop the original column 
df = df.drop(columns=['Hero|Publisher'])
df.head(5)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %%
## examining a single value from the coordinates col
Measurements = df.loc[0,"Measurements"]
print(type(Measurements))
Measurements
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
Measurements = Measurements.replace("'",'"')
Measurements
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
## now we can use json.loads
fixed_Measurements = json.loads(Measurements)
print(type(fixed_Measurements))
fixed_Measurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
## use .str.replace to replace all single quotes
df['Measurements'] = df['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
df['Measurements'] = df['Measurements'].apply(json.loads)
df['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
## check a single value after transformation
test_cMeasurements = df.loc[0, 'Measurements']
print(type(test_cMeasurements))
test_cMeasurements
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
Height_Weight = df['Measurements'].apply(pd.Series)
Height_Weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# concat long_lat with original dataframe
df = pd.concat((df, Height_Weight), axis = 1)
df.head(5)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# ...

# %%
df = df.drop(columns=['Measurements'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %%
df['Height'] = pd.to_numeric(df['Height'].str.extract('(\d+\.\d+)')[0])
df['Weight'] = pd.to_numeric(df['Weight'].str.extract('(\d+\.\d+)')[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics   203.0   441.0
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0
# 2       Abin Sur          DC Comics   185.0    90.0
# 3    Abomination      Marvel Comics   203.0   441.0
# 4  Absorbing Man      Marvel Comics   193.0   122.0

# %%
## showing the lists are really strings
df1.loc[2,'Powers']
# Out:
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
# Original string
powers_string = "Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner"

# Format as JSON
formatted_json = json.dumps(powers_string)

# Check the result
print(formatted_json)
# Out:
# "Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner"

# %%
# Split the comma-separated string into a list of powers
df1['Powers'] = df1['Powers'].str.split(',')

# Check the results
df1['Powers'].head()
# Out:
# 0      [Agility, Super Strength, Stamina, Super Speed]
# 1    [Accelerated Healing, Durability, Longevity, S...
# 2    [Agility, Accelerated Healing, Cold Resistance...
# 3                                 [Lantern Power Ring]
# 4    [Accelerated Healing, Intelligence, Super Stre...
# Name: Powers, dtype: object

# %%
df1['Powers'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
exploded = df1.explode('Powers')
result_df = exploded[['hero_names', 'Powers']]
result_df.head()
# Out:
#   hero_names               Powers
# 0    3-D Man              Agility
# 0    3-D Man       Super Strength
# 0    3-D Man              Stamina
# 0    3-D Man          Super Speed
# 1     A-Bomb  Accelerated Healing

# %%
# Get unique values from the 'Powers' column
cols_to_make = exploded['Powers'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
# Check if each hero has a specific power and create new columns
for col in cols_to_make:
    result_df[col] = result_df['Powers'] == col

# %%
# Display the first 5 rows
result_df.head()
# Out:
#   hero_names               Powers  Agility  Super Strength  Stamina  \
# 0    3-D Man              Agility     True           False    False
# 0    3-D Man       Super Strength    False            True    False
# 0    3-D Man              Stamina    False           False     True
# 0    3-D Man          Super Speed    False           False    False
# 1     A-Bomb  Accelerated Healing    False           False    False
#
#    Super Speed  Accelerated Healing  Durability  Longevity  Camouflage  ...  \
# 0        False                False       False      False       False  ...
# 0        False                False       False      False       False  ...
# 0        False                False       False      False       False  ...
# 0         True                False       False      False       False  ...
# 1        False                 True       False      False       False  ...
#
#    Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# ...

# %%
# Pivot the DataFrame
pivoted_df = result_df.pivot_table(index='hero_names', columns='Powers', fill_value=False)

# Remove the multi-level index for columns
pivoted_df.columns = pivoted_df.columns.droplevel()

# Reset the index to make 'hero_names' a regular column
pivoted_df = pivoted_df.reset_index()

# Display the first 5 rows
pivoted_df.head()
# Out:
# Powers   hero_names Accelerated Healing Adaptation Agility Animal Attributes  \
# 0           3-D Man               False      False     0.0             False
# 1            A-Bomb                 1.0      False   False             False
# 2        Abe Sapien                 1.0      False     0.0             False
# 3          Abin Sur               False      False   False             False
# 4       Abomination                 1.0      False   False             False
#
# Powers Animal Control Animal Oriented Powers Animation Anti-Gravity  \
# 0               False                  False     False        False
# 1               False                  False     False        False
# 2               False                  False     False        False
# 3               False                  False     False        False
# 4               False                  False       0.0        False
#
# Powers Astral Projection  ... Vision - Thermal Vision - X-Ray Vitakinesis  \
# ...

# %%
# Rename 'hero_names' to 'Hero' in pivoted_df
pivoted_df.rename(columns={'hero_names': 'Hero'}, inplace=True)

# Merge the two DataFrames on 'Hero'
merged_df = pd.merge(df, pivoted_df, on='Hero')

# Display the first 5 rows of the merged DataFrame
merged_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Vision - Thermal  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...            False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...            False
# 2       Abin Sur          DC Comics   185.0    90.0  ...            False
# 3    Abomination      Marvel Comics   203.0   441.0  ...            False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...            False
#
#   Vision - X-Ray Vitakinesis Wallcrawling Water Control Weapon-based Powers  \
# ...

# %%
# Filter superheroes with and without Super Speed
superheroes_with_super_speed = unique_heroes_df[unique_heroes_df['Super Speed'] == True]
superheroes_without_super_speed = unique_heroes_df[unique_heroes_df['Super Speed'] == False]

# Calculate the average weight for each group
average_weight_with_super_speed = superheroes_with_super_speed['Weight'].mean()
average_weight_without_super_speed = superheroes_without_super_speed['Weight'].mean()

# Print the results
print(f"Average weight of superheroes with Super Speed: {average_weight_with_super_speed:.2f} kg")
print(f"Average weight of superheroes without Super Speed: {average_weight_without_super_speed:.2f} kg")
# Out:
# C:\Users\Shaun\AppData\Local\Temp\ipykernel_9948\3910039978.py:2: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   superheroes_with_super_speed = unique_heroes_df[unique_heroes_df['Super Speed'] == True]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 2
#       1 # Filter superheroes with and without Super Speed
# ----> 2 superheroes_with_super_speed = unique_heroes_df[unique_heroes_df['Super Speed'] == True]
#       3 superheroes_without_super_speed = unique_heroes_df[unique_heroes_df['Super Speed'] == False]
#       5 # Calculate the average weight for each group
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:3794, in DataFrame.__getitem__(self, key)
#    3792 # Do we have a (boolean) DataFrame?
#    3793 if isinstance(key, DataFrame):
# -> 3794     return self.where(key)
# ...

# %%
# Check unique values in the 'Super Speed' column
unique_super_speed_values = unique_heroes_df['Super Speed'].value_counts().index
print("Unique values in 'Super Speed' column:", unique_super_speed_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9948\1419770883.py in ?()
#       1 # Check unique values in the 'Super Speed' column
# ----> 2 unique_super_speed_values = unique_heroes_df['Super Speed'].squeeze().unique()
#       3 print("Unique values in 'Super Speed' column:", unique_super_speed_values)
#       4
#
# ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
# Calculate the average height of heroes for each publisher
average_height_by_publisher = merged_df.groupby('Publisher')['Height'].mean()

print("Average height of heroes for each publisher:")
print(average_height_by_publisher)
